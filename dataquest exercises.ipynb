# %% [markdown]
# # Title
#
# ## short intro
# ### what project is about
# ### goal of the project

# %%
from csv import reader

### The Google Play data set ###
opened_file = open('googleplaystore.csv')
read_file = reader(opened_file)
android = list(read_file)
android_header = android[0]
android = android[1:]

### The App Store data set ###
opened_file = open('AppleStore.csv')
read_file = reader(opened_file)
ios = list(read_file)
ios_header = ios[0]
ios = ios[1:]

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n')
    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of colums:', len(dataset[0]))

# %%
print(android_header)
print('\n')
explore_data(android, 0, 1)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']

# %%
print(ios_header)
print('\n')
explore_data(ios, 0, 1)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']

# %%
for app in android:
    name = app[0]
    if name == 'Instagram':
        print(app)
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %%
duplicate_apps = []
android_unique_apps = []

for app in android:
    name = app[0]
    if name in android_unique_apps:
        duplicate_apps.append(name)
    else:
        android_unique_apps.append(name)

print('Num dups: ', len(duplicate_apps))
print('\n')
print('Examples of dup apps:', duplicate_apps[:5])
# Out:
# Num dups:  1181
#
#
# Examples of dup apps: ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings']

# %%
for app in android:
    name = app[0]
    if name == 'Instagram':
        print(app)
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %%
name_and_reviews = {'Instagram': 66577313, 'Facebook': 78158306}
print('LinkedIn' not in name_and_reviews)
print('Instagram' not in name_and_reviews)
# Out:
# True
# False

# %%
reviews_max = {}

for app in android:
    name = app[0]
    for rev in app[3]:
        n_reviews = app[3]
        if name in reviews_max and reviews_max[name] < n_reviews:
            reviews_max[name] = n_reviews
        elif name not in reviews_max:
            reviews_max[name] = n_reviews

# %%
print(len(reviews_max))
# Out:
# 9660

# %%
reviews_max = {}

android_clean = []
already_added = []

for app in android[1:]:
    name = app[0]
    for rev in app[3]:
        n_reviews = app[3]
                
        if name in reviews_max and reviews_max[name] < n_reviews:
            reviews_max[name] = n_reviews
        elif name not in reviews_max:
            reviews_max[name] = n_reviews
        
        if n_reviews == reviews_max[name] and name not in already_added:
            android_clean.append(app)
            already_added.append(name)

# %%
android_clean
# Out:
# [['Coloring book moana',
#   'ART_AND_DESIGN',
#   '3.9',
#   '967',
#   '14M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Pretend Play',
#   'January 15, 2018',
#   '2.0.0',
#   '4.0.3 and up'],
#  ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   'ART_AND_DESIGN',
#   '4.7',
#   '87510',
#   '8.7M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design',
#   'August 1, 2018',
#   '1.2.4',
#   '4.0.3 and up'],
#  ['Sketch - Draw & Paint',
#   'ART_AND_DESIGN',
#   '4.5',
#   '215644',
#   '25M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Art & Design',
#   'June 8, 2018',
#   'Varies with device',
#   '4.2 and up'],
#  ['Pixel Draw - Number Art Coloring Book',
#   'ART_AND_DESIGN',
#   '4.3',
#   '967',
#   '2.8M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Creativity',
#   'June 20, 2018',
#   '1.1',
#   '4.4 and up'],
#  ['Paper flowers instructions',
#   'ART_AND_DESIGN',
#   '4.4',
# ...

# %%
already_added
# Out:
# ['Coloring book moana',
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#  'Sketch - Draw & Paint',
#  'Pixel Draw - Number Art Coloring Book',
#  'Paper flowers instructions',
#  'Smoke Effect Photo Maker - Smoke Editor',
#  'Infinite Painter',
#  'Garden Coloring Book',
#  'Kids Paint Free - Drawing Fun',
#  'Text on Photo - Fonteee',
#  'Name Art Photo Editor - Focus n Filters',
#  'Tattoo Name On My Photo Editor',
#  'Mandala Coloring Book',
#  '3D Color Pixel by Number - Sandbox Art Coloring',
#  'Learn To Draw Kawaii Characters',
#  'Photo Designer - Write your name with shapes',
#  '350 Diy Room Decor Ideas',
#  'FlipaClip - Cartoon animation',
#  'ibis Paint X',
#  'Logo Maker - Small Business',
#  "Boys Photo Editor - Six Pack & Men's Suit",
#  'Superheroes Wallpapers | 4K Backgrounds',
#  'Mcqueen Coloring pages',
#  'HD Mickey Minnie Wallpapers',
#  'Harley Quinn wallpapers HD',
#  'Colorfit - Drawing & Coloring',
#  'Animated Photo Editor',
# ...

# %%
print(len(already_added))
print(type(already_added))
# Out:
# 9659
# <class 'list'>

# %%
already_added[0:1]
# Out:
# ['Coloring book moana']

# %%
print(len(android_clean))
print(type(android_clean))
# Out:
# 9659
# <class 'list'>

# %%
android_clean[0:1]
# Out:
# [['Coloring book moana',
#   'ART_AND_DESIGN',
#   '3.9',
#   '967',
#   '14M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Art & Design;Pretend Play',
#   'January 15, 2018',
#   '2.0.0',
#   '4.0.3 and up']]

# %% [markdown]
# ## Removing non-English apps

# %%
print(ios_header)
print('\n')
print(ios[:1])
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# [['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']]

# %%
print(android_header)
print('\n')
print(android[:1])
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# [['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']]

# %%
# def is_english(s):
#     for i in s:
#         if ord(i) > 127:
#             return False   
#     return True

# %%
print('😜',ord('😜'))
print('™', ord('™'))

# %%
# v2
def is_english(s):
    counter = 0

    for i in s:
        if ord(i) > 127:
            counter +=1
        if counter > 2:
            return False
    return True

# %%
# is_english('Docs To Go™ Free Office Suite')

# %%
# is_english('爱奇艺PPS -《欢乐颂2》电视剧热播')

# %%
# is_english('Instagram')

# %%
# is_english('Instachat 😜')

# %% [markdown]
# # Clean app lists, English only

# %%
ios_english = [] #track_name index=1
ios_english_names = []
android_english = [] #App index=1
android_english_names = []

for app in ios:
    name = app[1]
    ios_english_names.append(name)

    if is_english(name) == True:
        ios_english.append(app)
    
for app in android_clean:
    name = app[0]
    android_english_names.append(name)
    
    if is_english(name) == True:
        android_english.append(app)

# %%
print(len(ios_english_names))
print(len(android_english_names))
# Out:
# 7197
# 9659

# %%
print('len ios:', len(ios))
print('len ios_english:', len(ios_english))
# print('difference:', len(ios) - len(ios_english))
print('\n')
print(ios_english[:1])
# Out:
# len ios: 7197
# len ios_english: 6155
#
#
# [['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']]

# %%
print('len android:', len(android))
print('len android_clean:', len(android_clean))
print('len android_english:', len(android_english))
# print('difference android_clean - android_english :', len(android_clean) - len(android_english))
print('\n')
print(android_english[:1])
# Out:
# len android: 10841
# len android_clean: 9659
# len android_english: 9597
#
#
# [['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']]

# %% [markdown]
# # Free apps

# %%
ios_header[4]
# Out:
# 'price'

# %%
android_header[7]
# Out:
# 'Price'

# %%
ios_english_free = []
ios_english_free_names = []

for app in ios_english:
    name = app[1]
    price = float(app[4])
    if price == 0.0:
        ios_english_free.append(app) 
        ios_english_free_names.append(name)

# %%
print(ios_english_free[:2])
# Out:
# [['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1'], ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']]

# %%
android_english_free = []
android_english_free_names = []
android_price_list = []

for app in android_english:
    name = app[0]
    price = app[7]
    if price not in android_price_list:
        android_price_list.append(price)
#     if '$' in price:
#         android_dollar_sign.append(app)
#     else:
#         price = float(app[7])
#         if price == 0.0:
#             android_english_free.append(app)
#             android_english_free_names.append(name)
print(android_price_list)
# Out:
# ['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99', '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49', '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99', '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99', '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70', '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99', '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50', '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99', '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75', '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08', '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46', '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95', '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61', '$394.99', '$1.26', 'Everyone', '$1.20', '$1.04']
